# %% [markdown]
# <a href="https://colab.research.google.com/github/imyunhee/front-end/blob/master/overwrite_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow           #colab용 cv2.imshow

# %%
image_path = "/content/drive/MyDrive/lab_image.jpg"
image = cv2.imread(image_path)
image = cv2.resize(image, (300,400))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x7F4EB75B36A0>

# %%
hsy_img = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
cv2_imshow(hsy_img)

save_path = "/content/drive/MyDrive/"
cv2.imwrite(save_path + 'save_image.jpg', hsy_img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x7F4EB75B3AC0>
# True

# %%
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)

save_path = "/content/drive/MyDrive/"
cv2.imwrite(save_path +'save_image.jpg', gray_img)
# Out:
# <PIL.Image.Image image mode=L size=300x400 at 0x7F4EB7616EB0>
# True

# %%
save_image = cv2.imread("/content/drive/MyDrive/save_image.jpg")
cv2_imshow(save_image)
# Out:
# <PIL.Image.Image image mode=RGB size=300x400 at 0x7F4EB75B3D00>
